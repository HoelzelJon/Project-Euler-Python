# %%
def gcd(a, b):
    while b != 0:
        t = b
        b = a % b
        a = t
    return a

def R(M):
    
    sum = 0.0
    for q in range((M+2) // 2 , M+1):
        for p in range(max(1, M-q), q):
            if (gcd(q, p) == 1):
                sum += 1.0 / (p * q)
    return sum

def S(N):
    sum = 1.5
    for i in range(4, N+1):
        sum += R(i)
    return sum

for x in range(2, 100):
    print("R(X)=%f"%(x, R(x)))
# Out:
# x=2, R(X)=0.500000
# x=3, R(X)=1.000000
# x=4, R(X)=0.833333
# x=5, R(X)=0.916667
# x=6, R(X)=0.700000
# x=7, R(X)=0.850000
# x=8, R(X)=0.709524
# x=9, R(X)=0.746429
# x=10, R(X)=0.658730
# x=11, R(X)=0.766270
# x=12, R(X)=0.619481
# x=13, R(X)=0.738709
# x=14, R(X)=0.629448
# x=15, R(X)=0.650475
# x=16, R(X)=0.626363
# x=17, R(X)=0.698866
# x=18, R(X)=0.587195
# x=19, R(X)=0.683953
# x=20, R(X)=0.593329
# x=21, R(X)=0.622228
# x=22, R(X)=0.594998
# x=23, R(X)=0.660470
# x=24, R(X)=0.569401
# x=25, R(X)=0.634372
# x=26, R(X)=0.584132
# x=27, R(X)=0.609202
# x=28, R(X)=0.575390
# x=29, R(X)=0.635420
# x=30, R(X)=0.550004
# x=31, R(X)=0.628871
# x=32, R(X)=0.574004
# x=33, R(X)=0.589267
# x=34, R(X)=0.568812
# x=35, R(X)=0.595160
# x=36, R(X)=0.550026
# x=37, R(X)=0.612826
# x=38, R(X)=0.563195
# x=39, R(X)=0.578926
# x=40, R(X)=0.553611
# x=41, R(X)=0.604355
# x=42, R(X)=0.540022
# x=43, R(X)=0.600622
# x=44, R(X)=0.554684
# x=45, R(X)=0.563229
# x=46, R(X)=0.554480
# ...
